# %%
Code : BFS Traversal

# %%
## Read input as specified in the question.
## Print output as specified in the question.
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
        
    def containsEdge(self, v1, v2):
        return True if self.adjMatrix[v1][v2] > 0 else False
        
    def __str__(self):
        return str(self.adjMatrix)
    
    def BFS_Helper(self,sv,visited):
        q=queue.Queue()
        q.put(sv)
        visited[sv]=True
        while not q.empty():
            u=q.get()
            print(u,end=" ")
            for i in range(self.nVertices):
                if self.adjMatrix[u][i]>0 and visited[i] is False:
                    q.put(i)
                    visited[i]=True
                    
    def BFS(self):
        visited=[False for i in range(self.nVertices)]
        for i in range(self.nVertices):
            if visited[i] is False:
                self.BFS_Helper(i,visited)
                
                
li=[int(x) for x in input().split()]
m,n=li[0],li[1]
g=Graph(m)
for i in range(n):
    l=[int(x) for x in input().split()]
    v1,v2=l[0],l[1]
    g.addEdge(v1,v2)
g.BFS()

# %%
Code : Has Path

# %%
import queue
class Graph:
    def __init__(self, nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for i in range(nVertices)] for j in range(nVertices)]
       
    
    def addEdge(self, v1, v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
        
    def hasPathHelper(self, v1, v2, visited):
        if v1==v2:
            return True
        q=queue.Queue()
        q.put(v1)
        visited[v1]=True
        while not q.empty():
            cur=q.get()
            for i in range(self.nVertices):
                if self.adjMatrix[cur][i]==1 and visited[i]==False:
                    q.put(i)
                    visited[i]=True
                    if i==v2:
                        return True
        return False
    
    
    def hasPath(self, v1, v2, n):
        visited = [False] * n
        return self.hasPathHelper(v1, v2, visited)
                
v, e = [int (i) for i in input().split()[:2]]
g = Graph(v)
for i in range(e):
    a, b = [int(x) for x in input().split()[:2]]
    g.addEdge(a, b)
    
v1, v2 = [int (r) for r in input().split()[:2]]
if g.hasPath(v1, v2, v):
    print("true")
else:
    print("false")

# %%
Code : Get Path - DFS

# %%
import sys
sys.setrecursionlimit(1000000)

class Graph:
    def __init__(self, nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for i in range(nVertices)] for j in range(nVertices)]
       
    
    def addEdge(self, v1, v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
        
    def getPathHelper(self, v1, v2, visited,list):

        if v1 == v2:
            list = [v2]
            return list
        
        visited[v1] = True
        
        for i in range(self.nVertices):
            if self.adjMatrix[v1][i] > 0  and visited[i] is False:
                smallAns = self.getPathHelper(i, v2, visited, list)
                if smallAns is not None:
                    smallAns.append(v1)
                    return smallAns 
        return None
    
    
    def getPath(self, v1, v2, n):
        
        visited = [False] * n
        return self.getPathHelper(v1, v2, visited, [])
                    

v, e = [int (i) for i in input().split()[:2]]
g = Graph(v)
for i in range(e):
    a, b = [int(x) for x in input().split()[:2]]
    g.addEdge(a, b)
    
v1, v2 = [int (r) for r in input().split()[:2]]
list = g.getPath(v1, v2, v)
if list:
    for i in list:
        print(i, end = " ")

# %%
Code : Get Path - BFS

# %%
class Graph:
    def __init__(self, nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for i in range(nVertices)] for j in range(nVertices)]
           
    def addEdge(self, v1, v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
    
    def getPath(self, v1, v2):        
        p = {}
        visited = [False] * self.nVertices
        q=[]
        q.append(v1)
        visited[v1] = True
        while q:
            f=q.pop(0)
            if f== v2:
                return p
            for i in range(self.nVertices):
                if self.adjMatrix[f][i] > 0 and visited[i] is False:
                    q.append(i)
                    visited[i] = True
                    p[i] = f      
        return None
 

v, e = [int (i) for i in input().split()[:2]]
g = Graph(v)

for i in range(e):
    a, b = [int(x) for x in input().split()[:2]]
    g.addEdge(a, b)    
v1, v2 = [int (r) for r in input().split()[:2]]

parent = g.getPath(v1, v2)

if parent is not None:

    list = [v2]
    prev = v2
    
    while (1):
        prev = parent[prev]
        list.append(prev)
        if prev == v1:
            break

    for j in list:
        print(j, end = " ")

# %%
Code : Is Connected ?

# %%
import queue
from sys import stdin, setrecursionlimit
setrecursionlimit(10**6)
class Graph:
    def __init__(self, nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self, v1, v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
    
    def removeEdge(self):
        if self.containsEdge(v1, v2) is False :
            return
        self.adjMatrix[v1][v2] = 0
        self.adjMatrix[v2][v1] = 0
        
    def containsEdge(self, v1, v2):
        if self.adjMatrix[v1][v2] > 0:
            return True
        else: 
            return False
        
    def __str__(self):
        return str(self.adjMatrix)
    
        
        
    def __bfs(self, sv, visited) :
        q = queue.Queue()
        q.put(sv)
        
        visited[sv] = True
        
        while q.empty() is False :
            u = q.get()
            print(u, end = ' ')
            
            for i in range(self.nVertices) :
                if self.adjMatrix[u][i] > 0 and visited[i] is False :
                    q.put(i)
                    visited[i] = True
        
        
    def bfs(self) :
        visited = [False for i in range(self.nVertices)]
        
        for i in range(self.nVertices) :
            if visited[i] is False :
                self.__bfs(i, visited)
                
    
    def __getPathBFS(self, sv, ev, visited) :
        mapp = {}
        q = queue.Queue()
        
        if self.adjMatrix[sv][ev] == 1 and sv == ev :
            ans = []
            ans.append(sv)
            return ans
        
        q.put(sv)
        visited[sv] = True
        
        while q.empty() is False :
            front = q.get()
            
            for i in range(self.nVertices) :
                if self.adjMatrix[front][i] == 1 and visited[i] is False :
                    mapp[i] = front
                    q.put(i)
                    
                    visited[i] = True
                    
                    if i == ev :
                        ans = []
                        ans.append(ev)
                        value = mapp[ev]
                        
                        while value != sv :
                            ans.append(value)
                            value = mapp[value]
                        
                        ans.append(value)
                        return ans
    
        return []
        
        
    def getPathBFS(self, sv, ev) :
        visited = [False for i in range(self.nVertices)]
        return self.__getPathBFS(sv, ev, visited)
        
   
    def dfs(self, sv, visited) :
        visited[sv] = True
        
        for i in range(self.nVertices) :
            if self.adjMatrix[sv][i] == 1 and not visited[i] :
                self.dfs(i, visited)
                visited[i] = True
        
        
    def isConnected(self) :
        visited = [False for i in range(self.nVertices)]
        self.dfs(0, visited)
        
        for boolVal in visited :
            if not boolVal:
                return False
        return True
       

# Main
li = stdin.readline().strip().split()
V = int(li[0])
E = int(li[1])
if V==0:
    print('true')
else:
    g = Graph(V)

    for i in range(E) :
        arr = stdin.readline().strip().split()
        fv = int(arr[0])
        sv = int(arr[1])
        g.addEdge(fv, sv)

    print()  
    if g.isConnected() :
        print('true')
    else :
        print('false')

# %%
Code : All connected components

# %%
## Read input as specified in the question.
## Print output as specified in the question.
## Read input as specified in the question.
## Print output as specified in the question
import queue
class graph:
    
    def __init__(self, vertices):
        self.vertices = vertices
        self.matrix = [ [0 for i in range(self.vertices)] for j in range(self.vertices)]
        
    def edge(self, v1 , v2):
        
        self.matrix[v1][v2]=1
        self.matrix[v2][v1]=1
    
    def connected(self,v , sv , visited):
        q=queue.Queue()
        q.put(sv)
        li=[]
        li.append(sv)
        while q.qsize() !=0:
            a =q.get()
            visited[a]= True
            for i in range(v):
                if visited[i]== False and self.matrix[a][i] ==1:
                    q.put(i)
                    visited[i]=True
                    li.append(i)
        
        li.sort()
        print(*li)
            
        
    




li = [int(x) for x in input().split()]
v = li[0]
e = li[1]
g = graph(v)
for i in range(e):
    a, b = [int(x) for x in input().split()]
    g.edge(a, b)
visited = [False for i in range(v)]
for i in range(v):
    if visited[i]==False:
        g.connected(v,i,visited)
    

































'''class Graph:
    def __init__(self, nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for i in range(nVertices)] for j in range(nVertices)]
       
    
    def addEdge(self, v1, v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
        
    def __dfsHelper(self, sv, visited, list):
        list.append(sv)
        visited[sv] = True 
        for i in range(self.nVertices):
            if self.adjMatrix[sv][i] > 0 and visited[i] is False:
                self.__dfsHelper(i, visited, list)
            
        return list
    
    def dfs(self):         
        visited = [False for i in range(self.nVertices) ]
        final_list = []
        for i in range(self.nVertices):
            if not visited[i]:
                cc = self.__dfsHelper(i, visited, [])
                final_list.append(cc)
        return final_list
    
    
v, e = [int (i) for i in input().split()[:2]]
g = Graph(v)

for i in range(e):
    a, b = [int(x) for x in input().split()[:2]]
    g.addEdge(a, b)  
    
list = g.dfs()

for i in list:
    i.sort()
    for j in i:
        
        print(j, end = " ")
    print()'''
