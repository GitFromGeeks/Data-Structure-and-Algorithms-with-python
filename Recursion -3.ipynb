# %%
Return Subsequences

# %%
def subsequences(string):
    if len(string)==0:
        output=[]
        output.append("")
        return output
    smalleroutput=subsequences(string[1:])
    output=[]
    for i in smalleroutput:
        output.append(i)
    for i in smalleroutput:
        withOthIndex=string[0]+i
        output.append(withOthIndex)
    return output

string = input()
ans = subsequences(string)
for ele in ans:
    print(ele)

# %%
Return Keypad

# %%
def getstring(d):
    if d==2:
        return "abc"
    if d==3:
        return "def"
    if d==4:
        return "ghi"
    if d==5:
        return "jkl"
    if d==6:
        return "mno"
    if d==7:
        return "pqrs"
    if d==8:
        return "tuv"
    if d==9:
        return "wxyz"
    return ""


def keypad(n):
    if n==0:
        output=[]
        output.append("")
        return output
    
    smallernumber=n//10
    lastdigit=n%10
    
    smalleroutput=keypad(smallernumber)
    optionsforlastdigit=getstring(lastdigit)
    
    output=[]
    
    for i in smalleroutput:
        for j in optionsforlastdigit:
            option=i+j
            output.append(option)
    return output



    


n = int(input())
ans = keypad(n)
for s in ans:
    print(s)

# %%
Print Subsequences

# %%
def getstring(d):
    if d==2:
        return "abc"
    if d==3:
        return "def"
    if d==4:
        return "ghi"
    if d==5:
        return "jkl"
    if d==6:
        return "mno"
    if d==7:
        return "pqrs"
    if d==8:
        return "tuv"
    if d==9:
        return "wxyz"
    return ""


def keypad(n):
    if n==0:
        output=[]
        output.append("")
        return output
    
    smallernumber=n//10
    lastdigit=n%10
    
    smalleroutput=keypad(smallernumber)
    optionsforlastdigit=getstring(lastdigit)
    
    output=[]
    
    for i in smalleroutput:
        for j in optionsforlastdigit:
            option=i+j
            output.append(option)
    return output



    


n = int(input())
ans = keypad(n)
for s in ans:
    print(s)

# %%
Print Keypad

# %%
def getstring(d):
    if d==2:
        return "abc"
    if d==3:
        return "def"
    if d==4:
        return "ghi"
    if d==5:
        return "jkl"
    if d==6:
        return "mno"
    if d==7:
        return "pqrs"
    if d==8:
        return "tuv"
    if d==9:
        return "wxyz"
    return ""



def keypad(num,output=""):
    if num==0:
        print(output)
        return
    smallernumber=num//10
    lastdigit=num%10
    optionsforlastdigit=getstring(lastdigit)
    for c in optionsforlastdigit:
        newout=c+output
        keypad(smallernumber,newout)
num=int(input())
keypad(num)

# %%
Return subsets sum to K

# %%
import sys
sys.setrecursionlimit(10 ** 8)

def subsetsSumK(arr,k):
  n=len(arr)
  if n == 1:
    if arr[0]==k:
      output = [[k]]
      return output
    else:
      output = []
      return output
  
  output1 = subsetsSumK(arr[:-1], k)
  output2 = subsetsSumK(arr[:-1], k - arr[-1])

  for lst in output2:
    lst.append(arr[-1])

  if arr[-1] == k:
    output2.append([k])

  return output1 + output2







#taking input
def takeInput() :
    n = int(input().strip())

    if n == 0 :
        return list(), 0

    arr = [int(element) for element in list(input().strip().split(" "))]
    return arr, n


#printing the list of lists
def printListOfList(liOfLi) :
    for li in liOfLi :
        for elem in li :
            print(elem, end = " ")
        print()

#main
arr, n = takeInput()

if n != 0 :
    k = int(input().strip())
    liOfLi = subsetsSumK(arr, k)

    printListOfList(liOfLi)

# %%
Return subset of an array

# %%
## Read input as specified in the question.
## Print output as specified in the question.
def subsetOfArray(arr):
    
    if arr == []:
        return [[]]
	
    n = len(arr)
    output = subsetOfArray(arr[:n-1])
    outputLen = len(output)
	
    for  i in range(outputLen):
        output.append(output[i].copy())
        output[outputLen + i].append(arr[n-1])
    return output

n=int(input())
li=[int(x) for x in input().split()]
ans = subsetOfArray(li)
for i in ans:
    for j in i:
        print(j, end = ' ')
    print()

# %%
Return Permutations of a String

# %%
## Read input as specified in the question.
## Print output as specified in the question.
def subsetOfArray(arr):
    
    if arr == []:
        return [[]]
	
    n = len(arr)
    output = subsetOfArray(arr[:n-1])
    outputLen = len(output)
	
    for  i in range(outputLen):
        output.append(output[i].copy())
        output[outputLen + i].append(arr[n-1])
    return output

n=int(input())
li=[int(x) for x in input().split()]
ans = subsetOfArray(li)
for i in ans:
    for j in i:
        print(j, end = ' ')
    print()

# %%
Print Subsets of Array

# %%
## Read input as specified in the question.
## Print output as specified in the question.
def arraySubsets(arr, v=[]):
    if len(arr) == 0:
        for i in v[::-1]:
            print(i,end=" ")
        print()
        return
    
    arraySubsets(arr[:len(arr)- 1], v)
    v1 = [] + v
    v1.append(arr[len(arr)-1])
    arraySubsets(arr[:len(arr)-1], v1)
    
n = int(input())
arr = list(map(int, input().split()))
arraySubsets(arr)

# %%
Print Subset Sum to K

# %%
def subset(arr,n,k,output=[]):
    if k==0:
        for num in output:
            print(num,end=" ")
        print()
        return
    if n==0:
        return
    
    subset(arr,n-1, k,output)

    lst=[]
    lst.append(arr[n-1])
    lst=lst+output
    subset(arr,n-1, k-arr[n-1],lst)
    
n=int(input())
arr=[int(i) for i in input().split()[:n]]
k=int(input())
subset(arr,n, k)

# %%
Print Permutations of a String

# %%
"""def printPermutations(string,output=""):
    if len(string)==0:
        for i in output:
            print(i)
    for i in range(len(string)):
        start = string[i]
        remaining = permutations(string[:i] + string[i+1:])
        for val in remaining:
            output=output+[start + val]
            
string = input()
printPermutations(string)
"""
def printPermutations(string, val):
    if string == '':
        print(val)
        return
    
    n = len(string)
    for i in range(n):
        char = string[i]
        string = string[:i] + string[i+1:]
        printPermutations(string, val+char)
        
        string = string[:i] + char+ string[i:]
        
    

string = input()
printPermutations(string, '')
